# %%
import pandas as pd

# %%
data = {'Name' : ['Avijam', 'Insaan', 'Khushi', 'Nikki'],
       'Age': [2, 24, 50, 20],
       'Dept' : ['DBDA', 'DBDA', 'DAC', 'DAC'],
       'Marks': [99, 100, 22, 95]}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Dept  Marks
# 0  Avijam    2  DBDA     99
# 1  Insaan   24  DBDA    100
# 2  Khushi   50   DAC     22
# 3   Nikki   20   DAC     95

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Dept', 'Marks'], dtype='object')

# %%
df['Marks'].min()
# Out:
# np.int64(22)

# %%
df['Marks'].max()
# Out:
# np.int64(100)

# %%
df['Marks'].mean()
# Out:
# np.float64(79.0)

# %%
df['Dept'].value_counts()
# Out:
# Dept
# DBDA    2
# DAC     2
# Name: count, dtype: int64

# %%
df = pd.read_csv("C:/Users/dbda.STUDENTSDC/Downloads/solar.csv")

# %%
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# 5                  15.6               354  South
# ...

# %%
df[df["Installed Capacity (MW)"] > 500]
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 7     Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 7                  12.3               453  South

# %%
df[df["State"] == "New York"]
# Out:
#       State  Number of Solar Plants  Installed Capacity (MW)  \
# 6  New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh) Region
# 6                   4.1                84   East

# %%
df[["Average MW Per Plant", "Generation (GWh)"]]
df.filter(items=['Average MW Per Plant', 'Generation (GWh)'])
# Out:
#    Average MW Per Plant  Generation (GWh)
# 0                  15.3             10826
# 1                  22.5              2550
# 2                  21.6               557
# 3                   7.9               590
# 4                   5.9               235
# 5                  15.6               354
# 6                   4.1                84
# 7                  12.3               453

# %%
df.sort_values(by=["Generation (GWh)","Installed Capacity (MW)"], 
               ascending=[True,False])
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 6     New York                      13                       53
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 7      Florida                      15                      535
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 1      Arizona                      48                     1078
# 0   California                     289                     4395
#
#    Average MW Per Plant  Generation (GWh) Region
# 6                   4.1                84   East
# 4                   5.9               235   East
# 5                  15.6               354  South
# 7                  12.3               453  South
# 2                  21.6               557   West
# 3                   7.9               590  North
# ...

# %%
df.nlargest(5, "Generation (GWh)")
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 3     Chicago                      33                      261
# 2      Nevada                      11                      238
# 7     Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 3                   7.9               590  North
# 2                  21.6               557   West
# 7                  12.3               453  South

# %%
states = ["California", "Nevada", "Arizona", "Texas"]
filt = df.State.isin(states)
df.loc[filt]
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 2      Nevada                      11                      238
# 5       Texas                      12                      187
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 5                  15.6               354  South

# %%
df.groupby("Region")["Installed Capacity (MW)"].agg(['min','max'])
# Out:
#         min   max
# Region
# East     53   118
# North   261   261
# South   187   535
# West    238  4395

# %%
new_plant = {
    'State': 'North Carolina',
    'Installed Capacity (MW)': 148,
    'Average MW Per Plant': 669,
    'Generation (GWh)': 4.5,
    'Total Generation': 1162,
    'Region': 'North'
}
new_plant_df = pd.DataFrame([new_plant])
df = pd.concat([df,new_plant_df],ignore_index=True)
print(df.tail())
# Out:
#             State  Number of Solar Plants  Installed Capacity (MW)  \
# 4     Connecticut                    20.0                      118
# 5           Texas                    12.0                      187
# 6        New York                    13.0                       53
# 7         Florida                    15.0                      535
# 8  North Carolina                     NaN                      148
#
#    Average MW Per Plant  Generation (GWh) Region  Total Generation
# 4                   5.9             235.0   East               NaN
# 5                  15.6             354.0  South               NaN
# 6                   4.1              84.0   East               NaN
# 7                  12.3             453.0  South               NaN
# 8                 669.0               4.5  North            1162.0

# %%
df = pd.read_csv("C:/Users/dbda.STUDENTSDC/Downloads/gapminder2007.csv")

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df[df['continent'] == 'Asia']
# Out:
#                 country         pop continent  lifeExp     gdpPercap
# 0           Afghanistan    31889923      Asia   43.828    974.580338
# 7               Bahrain      708573      Asia   75.635  29796.048340
# 8            Bangladesh   150448339      Asia   64.062   1391.253792
# 18             Cambodia    14131858      Asia   59.723   1713.778686
# 24                China  1318683096      Asia   72.961   4959.114854
# 55     Hong Kong, China     6980412      Asia   82.208  39724.978670
# 58                India  1110396331      Asia   64.698   2452.210407
# 59            Indonesia   223547000      Asia   70.650   3540.651564
# 60                 Iran    69453570      Asia   70.964  11605.714490
# 61                 Iraq    27499638      Asia   59.545   4471.061906
# 63               Israel     6426679      Asia   80.745  25523.277100
# 66                Japan   127467972      Asia   82.603  31656.068060
# 67               Jordan     6053193      Asia   72.535   4519.461171
# ...

# %%
df.head(15)
# Out:
#                    country        pop continent  lifeExp     gdpPercap
# 0              Afghanistan   31889923      Asia   43.828    974.580338
# 1                  Albania    3600523    Europe   76.423   5937.029526
# 2                  Algeria   33333216    Africa   72.301   6223.367465
# 3                   Angola   12420476    Africa   42.731   4797.231267
# 4                Argentina   40301927  Americas   75.320  12779.379640
# 5                Australia   20434176   Oceania   81.235  34435.367440
# 6                  Austria    8199783    Europe   79.829  36126.492700
# 7                  Bahrain     708573      Asia   75.635  29796.048340
# 8               Bangladesh  150448339      Asia   64.062   1391.253792
# 9                  Belgium   10392226    Europe   79.441  33692.605080
# 10                   Benin    8078314    Africa   56.728   1441.284873
# 11                 Bolivia    9119152  Americas   65.554   3822.137084
# ...

# %%
df.tail(15)
# Out:
#                  country        pop continent  lifeExp     gdpPercap
# 127             Thailand   65068149      Asia   70.616   7458.396327
# 128                 Togo    5701579    Africa   58.420    882.969944
# 129  Trinidad and Tobago    1056608  Americas   69.819  18008.509240
# 130              Tunisia   10276158    Africa   73.923   7092.923025
# 131               Turkey   71158647    Europe   71.777   8458.276384
# 132               Uganda   29170398    Africa   51.542   1056.380121
# 133       United Kingdom   60776238    Europe   79.425  33203.261280
# 134        United States  301139947  Americas   78.242  42951.653090
# 135              Uruguay    3447496  Americas   76.384  10611.462990
# 136            Venezuela   26084662  Americas   73.747  11415.805690
# 137              Vietnam   85262356      Asia   74.249   2441.576404
# 138   West Bank and Gaza    4018332      Asia   73.422   3025.349798
# 139          Yemen, Rep.   22211743      Asia   62.698   2280.769906
# ...

# %%
df[df['lifeExp'].between(51,79)]
# Out:
#                 country        pop continent  lifeExp     gdpPercap
# 1               Albania    3600523    Europe   76.423   5937.029526
# 2               Algeria   33333216    Africa   72.301   6223.367465
# 4             Argentina   40301927  Americas   75.320  12779.379640
# 7               Bahrain     708573      Asia   75.635  29796.048340
# 8            Bangladesh  150448339      Asia   64.062   1391.253792
# ..                  ...        ...       ...      ...           ...
# 135             Uruguay    3447496  Americas   76.384  10611.462990
# 136           Venezuela   26084662  Americas   73.747  11415.805690
# 137             Vietnam   85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza    4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.   22211743      Asia   62.698   2280.769906
#
# [99 rows x 5 columns]

# %%
df[df['country'].isin(['India','America','France'])]
# Out:
#    country         pop continent  lifeExp     gdpPercap
# 44  France    61083916    Europe   80.657  30470.016700
# 58   India  1110396331      Asia   64.698   2452.210407

# %%
df[df['country'].str.startswith('A')]
# Out:
#        country       pop continent  lifeExp     gdpPercap
# 0  Afghanistan  31889923      Asia   43.828    974.580338
# 1      Albania   3600523    Europe   76.423   5937.029526
# 2      Algeria  33333216    Africa   72.301   6223.367465
# 3       Angola  12420476    Africa   42.731   4797.231267
# 4    Argentina  40301927  Americas   75.320  12779.379640
# 5    Australia  20434176   Oceania   81.235  34435.367440
# 6      Austria   8199783    Europe   79.829  36126.492700

# %%
df.groupby('continent')[['gdpPercap','pop']].agg(['min','max','mean'])

# df.groupby("Region")["Installed Capacity (MW)"].agg(['min','max'])
# Out:
#               gdpPercap                                 pop              \
#                     min          max          mean      min         max
# continent
# Africa       277.551859  13206.48452   3089.032605   199579   135031164
# Americas    1201.637154  42951.65309  11003.031625  1056608   301139947
# Asia         944.000000  47306.98978  12473.026870   708573  1318683096
# Europe      5937.029526  49357.19017  25054.481636   301931    82400996
# Oceania    25185.009110  34435.36744  29810.188275  4115771    20434176
#
#
#                    mean
# continent
# Africa     1.787576e+07
# Americas   3.595485e+07
# Asia       1.155138e+08
# Europe     1.953662e+07
# Oceania    1.227497e+07

# %%
df[['country','pop','lifeExp']]
# Out:
#                 country       pop  lifeExp
# 0           Afghanistan  31889923   43.828
# 1               Albania   3600523   76.423
# 2               Algeria  33333216   72.301
# 3                Angola  12420476   42.731
# 4             Argentina  40301927   75.320
# ..                  ...       ...      ...
# 137             Vietnam  85262356   74.249
# 138  West Bank and Gaza   4018332   73.422
# 139         Yemen, Rep.  22211743   62.698
# 140              Zambia  11746035   42.384
# 141            Zimbabwe  12311143   43.487
#
# [142 rows x 3 columns]

# %%
df.sort_values(by=['country','gdpPercap'], ascending=[True,False])
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.nlargest(20, 'pop')
# Out:
#               country         pop continent  lifeExp     gdpPercap
# 24              China  1318683096      Asia   72.961   4959.114854
# 58              India  1110396331      Asia   64.698   2452.210407
# 134     United States   301139947  Americas   78.242  42951.653090
# 59          Indonesia   223547000      Asia   70.650   3540.651564
# 14             Brazil   190010647  Americas   72.390   9065.800825
# 97           Pakistan   169270617      Asia   65.483   2605.947580
# 8          Bangladesh   150448339      Asia   64.062   1391.253792
# 94            Nigeria   135031164    Africa   46.859   2013.977305
# 66              Japan   127467972      Asia   82.603  31656.068060
# 82             Mexico   108700891  Americas   76.195  11977.574960
# 101       Philippines    91077287      Asia   71.688   3190.481016
# 137           Vietnam    85262356      Asia   74.249   2441.576404
# 47            Germany    82400996    Europe   79.406  32170.374420
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 4             Argentina  40301927  Americas   75.320  12779.379640
# 5             Australia  20434176   Oceania   81.235  34435.367440
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [141 rows x 5 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3             Argentina  40301927  Americas   75.320  12779.379640
# 4             Australia  20434176   Oceania   81.235  34435.367440
# ..                  ...       ...       ...      ...           ...
# 136             Vietnam  85262356      Asia   74.249   2441.576404
# 137  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 138         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 139              Zambia  11746035    Africa   42.384   1271.211593
# 140            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [141 rows x 5 columns]

# %%
df.columns = df.columns.str.title()

# %%
df
# Out:
#                 Country       Pop Continent  Lifeexp     Gdppercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3             Argentina  40301927  Americas   75.320  12779.379640
# 4             Australia  20434176   Oceania   81.235  34435.367440
# ..                  ...       ...       ...      ...           ...
# 136             Vietnam  85262356      Asia   74.249   2441.576404
# 137  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 138         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 139              Zambia  11746035    Africa   42.384   1271.211593
# 140            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [141 rows x 5 columns]

# %%
df = df.rename(columns={
    'Pop' : 'Population',
    'Gdppercap' : 'GDP_Percap'

})
df.columns
# Out:
# Index(['Country', 'Population', 'Continent', 'Lifeexp', 'GDP_Percap'], dtype='object')

# %%
df = pd.read_csv("C:/Users/dbda.STUDENTSDC/Downloads/gapminder2007.csv")

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.loc[df['continent'] == 'Africa', 'lifeExp'] += 2

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   74.301   6223.367465
# 3                Angola  12420476    Africa   44.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   44.384   1271.211593
# 141            Zimbabwe  12311143    Africa   45.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.loc[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, pop, continent, lifeExp, gdpPercap]
# Index: []

# %%
new_con = {
    'country': 'Demo',
    'pop': 1480,
    'continent': np.nan,
    'lifeExp': 4.5,
    'gdpPercap' : np.nan
}
new_condf = pd.DataFrame([new_con])
df = pd.concat([df,new_condf],ignore_index=True)
print(df.tail())
# Out:
#                 country       pop continent  lifeExp    gdpPercap
# 138  West Bank and Gaza   4018332      Asia   73.422  3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698  2280.769906
# 140              Zambia  11746035    Africa   44.384  1271.211593
# 141            Zimbabwe  12311143    Africa   45.487   469.709298
# 142                Demo      1480       NaN    4.500          NaN

# %%
df[df.select_dtypes(include='number').columns] = df.select_dtypes(include='number').fillna(0)
df.tail()
# Out:
#                 country       pop continent  lifeExp    gdpPercap
# 138  West Bank and Gaza   4018332      Asia   73.422  3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698  2280.769906
# 140              Zambia  11746035    Africa   44.384  1271.211593
# 141            Zimbabwe  12311143    Africa   45.487   469.709298
# 142                Demo      1480       NaN    4.500     0.000000
